# %%
import pandas as pd

# %%
import pandas as pd
data=[
    ["tester1","testcase1","passed"],
    ["tester2","testcase2","failed"],
    ["tester3","testcase3","failed"]
]
df=pd.DataFrame(data,columns=['tester','tescase','result'],index=[1,2,3])

# %%
# Out:
#   Cell In[6], line 1
#     df=pd.DataFrame(date,columns=["tester","tescase","result"]
#                                                               ^
# _IncompleteInputError: incomplete input

# %%
df
# Out:
#     tester    tescase  result
# 1  tester1  testcase1  passed
# 2  tester2  testcase2  failed
# 3  tester3  testcase3  failed

# %%
df.columns
# Out:
# Index(['tester', 'tescase', 'result'], dtype='object')

# %%
df.values
# Out:
# array([['tester1', 'testcase1', 'passed'],
#        ['tester2', 'testcase2', 'failed'],
#        ['tester3', 'testcase3', 'failed']], dtype=object)

# %%
table=pd.read_csv("test1.txt")
table
# Out:
#    1-batary life 2 day   100
# 0   2-sleep data    day    8
# 1  3-calary burn  2days  100

# %%
table
# Out:
#    1-batary life 2 day   100
# 0   2-sleep data    day    8
# 1  3-calary burn  2days  100

# %%
table
# Out:
#    1-batary life 2 day   100
# 0   2-sleep data    day    8
# 1  3-calary burn  2days  100

# %%
table.index=[1,2]
table
# Out:
#    1-batary life 2 day   100
# 1   2-sleep data    day    8
# 2  3-calary burn  2days  100

# %%
import pandas as panda

# %%
df=pd.read_csv(weather.txt)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df=pd.read_csv(weather.txt)
#       2 df
#
# NameError: name 'weather' is not defined

# %%
df
